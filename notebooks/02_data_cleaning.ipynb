# %% [markdown]
# # Data Cleaning

# %%
from pathlib import Path
import json
from src.cleaning import normalize_users
from src.utils import read_json, write_json

raw = read_json(Path('../data/data.json'))
users = normalize_users(raw)
print('Users:', len(users))
write_json(Path('../data/cleaned_data.json'), users)
