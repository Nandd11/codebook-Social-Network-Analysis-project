# %% [markdown]
# # People You May Know Recommender

# %%
from pathlib import Path
from src.utils import read_json
from src.recommender_people import people_you_may_know

users = read_json(Path('../data/cleaned_data.json'))
print(people_you_may_know(users, users[0]['id'], 5))
