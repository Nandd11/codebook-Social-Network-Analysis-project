# %% [markdown]
# # Pages You Might Like Recommender

# %%
from pathlib import Path
from src.utils import read_json
from src.recommender_pages import pages_you_might_like

users = read_json(Path('../data/cleaned_data.json'))
print(pages_you_might_like(users, users[0]['id'], 5))
